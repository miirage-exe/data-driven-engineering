# %% [markdown]
# <a href="https://colab.research.google.com/github/miirage-exe/data-driven-engineering/blob/main/data_driven_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Test
# Test 2
https://github.com/burn-research/data-driven-engineering-course2026/blob/main/Projects/assignments.md
